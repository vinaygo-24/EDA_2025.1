# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

visa_df = pd.read_csv(r"C:\Users\vinay\Documents\Naresh IT\Data_Files\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values

# %%
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
continent_table = pd.DataFrame(zip(keys,values))
continent_table.to_csv('continent_table.csv',index=False)

# %%
cat = visa_df.select_dtypes(include='object').columns
num = visa_df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cat[1:]
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),
                      columns=['Class','Frequency'])
    df.to_csv(f'C:\Users\vinay\Documents\Naresh IT\Data_Files\Frequency_table/{i}_df.csv',index=False)
# Out:
#   Cell In[12], line 6
#     df.to_csv(f'C:\Users\vinay\Documents\Naresh IT\Data_Files\Frequency_table/{i}_df.csv',index=False)
#                                                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# ## To store the File in Current Working directory ##

# %%
# step 1 : Get CWD
# step 2 : Folder name
# step 3 : File name

import os
directory = os.getcwd()                #Get CWD
folder_name = 'Frequency_table'        #Folder Name
for i in cat[1:]:
    file_name = f'{i}_df1.csv'         #File Name
    path = os.path.join(directory,folder_name,file_name)
    print(path)
# Out:
# C:\Users\vinay\Documents\Naresh IT\Pandas_Sessions(EDA)\Frequency_table\continent_df1.csv
# C:\Users\vinay\Documents\Naresh IT\Pandas_Sessions(EDA)\Frequency_table\education_of_employee_df1.csv
# C:\Users\vinay\Documents\Naresh IT\Pandas_Sessions(EDA)\Frequency_table\has_job_experience_df1.csv
# C:\Users\vinay\Documents\Naresh IT\Pandas_Sessions(EDA)\Frequency_table\requires_job_training_df1.csv
# C:\Users\vinay\Documents\Naresh IT\Pandas_Sessions(EDA)\Frequency_table\region_of_employment_df1.csv
# C:\Users\vinay\Documents\Naresh IT\Pandas_Sessions(EDA)\Frequency_table\unit_of_wage_df1.csv
# C:\Users\vinay\Documents\Naresh IT\Pandas_Sessions(EDA)\Frequency_table\full_time_position_df1.csv
# C:\Users\vinay\Documents\Naresh IT\Pandas_Sessions(EDA)\Frequency_table\case_status_df1.csv

# %%
import os
directory = os.getcwd()
folder_name = 'Frequency Table'

for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),
                      columns=['Class','Frequency'])
    file_name = f'{i}_df1.csv'
    path = os.path.join(directory,folder_name,file_name)
    df.to_csv(path,index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 12
#      10 file_name = f'{i}_df1.csv'
#      11 path = os.path.join(directory,folder_name,file_name)
# ---> 12 df.to_csv(path,index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ## To create a FOLDER in CWD and save the FILE in that FOLDER ##

# %%
import os
cwd = os.getcwd()
folder_name = '01_frequency_tables'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)

for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),
                     columns=['Class','Frequency'])
    file_name = f'{i}_df.csv'
    path = os.path.join(cwd,folder_name,file_name)
    df.to_csv(path,index=False)

# %% [markdown]
# ## To create a FOLDER in CWD and save the BAR CHART in that FOLDER ##

# %%
import os
cwd = os.getcwd()
folder_name = '02_Bar charts'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)

for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    plt.figure(figsize=(10,3))
    plt.bar(keys,values)
    plt.xlabel = 'Class'
    plt.ylabel = 'Frequency'
    file_name = f'{i}_df.png'
    path = os.path.join(cwd,folder_name,file_name)
    plt.savefig(path)
    plt.show()

# %% [markdown]
# ## To create a FOLDER in CWD and save the PIE CHART in that FOLDER ##

# %%
import os
cwd = os.getcwd()
folder_name = '03_Pie charts'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)

for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    plt.pie(values,
           labels=keys)
    file_name = f'{i}_df.png'
    path = os.path.join(cwd,folder_name,file_name)
    plt.savefig(path)
    plt.show()

# %% [markdown]
# # Next class

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

visa_df = pd.read_csv(r"C:\Users\vinay\Documents\Naresh IT\Data_Files\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
keys = visa_df['continent'].value_counts().keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values = visa_df['continent'].value_counts().values
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
plt.figure(figsize=(10,3))
plt.bar(keys,values)
plt.show()

# %%
cat = visa_df.select_dtypes(include='object').columns

# %% [markdown]
# ### Subplot ###

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %%
plt.figure(figsize=(12,12))
for i in range(1,len(cat)):
    plt.subplot(3,3,i)
    keys = visa_df['continent'].value_counts().keys()
    values = visa_df['continent'].value_counts().values
    plt.bar(keys,values)

# %%
plt.figure(figsize=(12,12))
for i in range(1,len(cat)):
    col = cat[i]
    plt.subplot(3,3,i)
    keys = visa_df[col].value_counts().keys()
    values = visa_df[col].value_counts().values
    plt.bar(keys,values)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

plt.figure(figsize=(12, 12))

for i in range(1, len(cat)):  # You can change to range(len(cat)) if you want all
    col = cat[i]
    plt.subplot(3, 3, i)

    value_counts = visa_df[col].value_counts()
    keys = value_counts.index
    values = value_counts.values

    # Generate colors using a colormap
    cmap = cm.get_cmap('Set3', len(keys))  # Try 'tab10', 'Set1', 'Set3', etc.
    colors = [cmap(j) for j in range(len(keys))]

    plt.bar(keys, values, color=colors)
    plt.title(col)
    plt.xticks(rotation=45)
    plt.tight_layout()
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_10764\1122800130.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Set3', len(keys))  # Try 'tab10', 'Set1', 'Set3', etc.
# C:\Users\vinay\AppData\Local\Temp\ipykernel_10764\1122800130.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Set3', len(keys))  # Try 'tab10', 'Set1', 'Set3', etc.
# ...
